# %% [markdown]
# <a href="https://colab.research.google.com/github/FEILXD/primera_base_datos/blob/main/inmercion_de_datos_aula_0_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

inmueble = pd.read_csv("/content/drive/MyDrive/inmuebles_bogota.csv")
inmueble.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
inmueble.shape
# Out:
# (9520, 8)

# %%
inmueble.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Banos', 'Area', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columnas = {"Baños":"Banos","Área":"Area"}
inmueble = inmueble.rename(columns = columnas)
inmueble.sample(10)
# Out:
#              Tipo                             Descripcion  Habitaciones  \
# 2458         Casa         Casa en venta en Barrios Unidos             8
# 2316         Casa               Casa en venta en Engativa             9
# 7463         Casa  Casa en venta en Bellavista Occidental             5
# 4954  Apartamento  Apartamento en venta en Barrios Unidos             3
# 2156         Casa           Casa en venta en San Patricio             4
# 8783  Apartamento         Apartamento en venta en Kennedy             3
# 8137         Casa                   Casa en venta en Suba             2
# 6617  Apartamento         Apartamento en venta en Usaquén             3
# 5492  Apartamento   Apartamento en venta en San Cristobal             2
# 425   Apartamento         Apartamento en venta en Usaquén             3
#
#       Banos  Area                 Barrio  \
# 2458      3   290         Barrios Unidos
# 2316      5   396               Engativa
# 7463      4   173  Bellavista Occidental
# ...

# %%
inmueble.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmueble.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
inmueble.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmueble["Valor"][300]
# Out:
# '$ 116.100.000'

# %%
type(inmueble["Valor"][300:305])
# Out:
# pandas.core.series.Series

# %%
inmueble.Area.mean()
# Out:
# 146.66470588235293

# %%
(inmueble.Barrio == "Chico Reservado")
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum((inmueble.Barrio == "Chico Reservado"))
# Out:
# 225

# %%
inmueble_chico = (inmueble.Barrio == "Chico Reservado")
type(inmueble.Barrio == "Chico Reservado")
# Out:
# pandas.core.series.Series

# %%
chico_reservado = inmueble[inmueble_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# ...

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
len(inmueble.Barrio.value_counts())
# Out:
# 149

# %%
inmueble.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
len(inmueble.UPZ.value_counts())
# Out:
# 63

# %%
inmueble_barrio = inmueble.Barrio.value_counts()
inmueble_barrio.plot.bar()
# Out:
# <Axes: >

# %%
inmueble_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %%
inmueble.sample(5)
# Out:
#              Tipo                               Descripcion  Habitaciones  \
# 6051         Casa       Casa en venta en Zona Noroccidental             3
# 7880  Apartamento         Apartamento en venta en La Sabana             3
# 1094  Apartamento           Apartamento en venta en Usaquén             3
# 4298  Apartamento              Apartamento en venta en Bosa             3
# 8016  Apartamento  Apartamento en venta en Lagos De Cordoba             4
#
#       Banos  Area              Barrio                                 UPZ  \
# 6051      2    95  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 7880      2   132           La Sabana                           La Sabana
# 1094      3   130             Usaquén                             Usaquén
# 4298      1    54                Bosa                        Bosa Central
# 8016      2    99    Lagos De Cordoba                                Niza
#
#                 Valor
# 6051    $ 435.000.000
# 7880    $ 460.000.000
# ...

# %%
inmueble.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmueble.Valor[0]
# Out:
# '$ 360.000.000'

# %%
valor = inmueble.Valor.str.split(expand=True)
inmueble["Moneda"] = valor[0]
inmueble["Precio"] = valor[1]
inmueble.sample(3)
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 7792  Apartamento        Apartamento en venta en Usaquén             1      1
# 4548  Apartamento  Apartamento en venta en Chico Navarra             4      6
# 8955         Casa          Casa en venta en San Patricio             6      6
#
#       Area         Barrio                                    UPZ  \
# 7792    39        Usaquén                                Usaquén
# 4548   316  Chico Navarra  USAQUÉN: Country Club + Santa Bárbara
# 8955   330   San Patricio  USAQUÉN: Country Club + Santa Bárbara
#
#                 Valor Moneda         Precio
# 7792    $ 260.000.000      $    260.000.000
# 4548  $ 1.900.000.000      $  1.900.000.000
# 8955  $ 1.900.000.000      $  1.900.000.000

# %%
inmueble.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
from re import RegexFlag
inmueble["Precio"] = inmueble["Precio"].str.replace(".","",regex=True)

# %%
inmueble[["Precio","Barrio"]]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmueble.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmueble["Precio_millon"] = inmueble.Precio.astype("float")/1000000
inmueble.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmueble.describe()
# Out:
#        Habitaciones        Banos           Area  Precio_millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %%
pd.set_option("display.precision",2)
pd.set_option("display.float_format",lambda x: "%.2f" % x)
inmueble.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %%
inmueble.loc[inmueble.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
inmueble.loc[inmueble.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_millon
# 8401         180.00

# %%
inmueble.loc[inmueble.Banos == 0]
# Out:
#           Tipo                         Descripcion  Habitaciones  Banos  Area  \
# 2910  Edificio  Edificio en venta en Santa Barbara            22      0  1080
# 8193      Casa      Casa en venta en Puente Aranda            15      0   450
# 9451      Casa               Casa en venta en Bosa            10      0   540
#
#              Barrio                                             UPZ  \
# 2910  Santa Barbara           USAQUÉN: Country Club + Santa Bárbara
# 8193  Puente Aranda  PUENTE ARANDA: Zona Industrial + Puente Aranda
# 9451           Bosa                                    Bosa Central
#
#                 Valor Moneda      Precio  Precio_millon
# 2910  $ 9.200.000.000      $  9200000000        9200.00
# 8193  $ 1.000.000.000      $  1000000000        1000.00
# 9451    $ 800.000.000      $   800000000         800.00

# %%
inmueble["Precio_millon"].plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,8))
grafica = sns.histplot(data=inmueble, x="Precio_millon", kde=True, hue="Tipo" )
grafica.set_title("Distribucion de valores de inmuebles en Bogota")
plt.xlim((50,1000))
plt.savefig("/content/drive/MyDrive/Colab Notebooks/inemrcion de datos/grafico0.1",format="png")
plt.show()

# %%
inmueble["Valor_m2_millones"] = inmueble["Precio_millon"]/inmueble["Area"]
inmueble.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_millon  Valor_m2_millones
# ...

# %%
inmueble.groupby("Barrio").mean()
# Out:
#                     Habitaciones  Banos   Area  Precio_millon  \
# Barrio
# Alameda                     3.00   2.00  97.00         580.00
# Alhambra                    3.00   2.94 190.41         752.35
# Andes Norte                 3.00   2.86 124.86         709.57
# Antonio Nariño              4.31   2.50 163.06         459.22
# Barrancas                   2.87   2.13  70.20         314.13
# ...                          ...    ...    ...            ...
# Villa Maria                 4.69   3.69 207.15         402.85
# Villas De Granada           3.45   2.32  86.59         282.30
# Villemar                    2.94   2.06  76.89         303.83
# Zona Franca                 2.00   1.00  54.00         160.00
# Zona Noroccidental          3.17   2.51 135.79         620.81
#
#                     Valor_m2_millones
# Barrio
# Alameda                          5.98
# Alhambra                         4.33
# Andes Norte                      6.05
# Antonio Nariño                   3.53
# ...

# %%
datos_barrio = inmueble.groupby("Barrio").sum()
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_millones
# Barrio
# Alameda                          5.98
# Alhambra                        73.56
# Andes Norte                     42.35
# ...

# %%
datos_barrio["Valor_m2_barrio"] = datos_barrio["Precio_millon"]/datos_barrio["Area"]
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_millones  Valor_m2_barrio
# Barrio
# Alameda                          5.98             5.98
# Alhambra                        73.56             3.95
# ...

# %%
m2_barrio = dict(datos_barrio["Valor_m2_barrio"])

# %%
inmueble["Valor_m2_barrio"] = inmueble["Barrio"].map(m2_barrio)
inmueble.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_millon  Valor_m2_millones  \
# ...

# %%
top_barrio = inmueble['Barrio'].value_counts()[:10].index

# %%
datos_barrio.reset_index(inplace=True)
datos_barrio
# Out:
#      index              Barrio  Habitaciones  Banos    Area  Precio_millon  \
# 0        0             Alameda             3      2      97         580.00
# 1        1            Alhambra            51     50    3237       12790.00
# 2        2         Andes Norte            21     20     874        4967.00
# 3        3      Antonio Nariño           207    120    7827       22042.65
# 4        4           Barrancas            43     32    1053        4712.00
# ..     ...                 ...           ...    ...     ...            ...
# 144    144         Villa Maria            61     48    2693        5237.00
# 145    145   Villas De Granada            76     51    1905        6210.62
# 146    146            Villemar            53     37    1384        5469.00
# 147    147         Zona Franca             2      1      54         160.00
# 148    148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_millones  Valor_m2_barrio
# ...

# %%
datos_barrio.query("Barrio in @top_barrio")
# Out:
#      index              Barrio  Habitaciones  Banos    Area  Precio_millon  \
# 5        5      Barrios Unidos          1525   1196   87799      259877.76
# 10      10                Bosa          1743    789   34879       93400.56
# 22      22            Cedritos          1458   1348   53711      270027.73
# 24      24           Chapinero           892    913   81248      372130.93
# 50      50            Engativa          1676   1077   59808      172711.73
# 63      63             Kennedy          2151   1233   61475      207963.65
# 125    125       Santa Barbara          1073   1162   54693      320097.80
# 132    132                Suba          1497   1202   61615      266406.04
# 138    138             Usaquén          3109   3044  148121      837710.36
# 148    148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_millones  Valor_m2_barrio
# 5              2070.61             2.96
# 10             1654.36             2.68
# ...

# %%
plt.figure(figsize=(10,8)) 
ax = sns.boxplot(x="Barrio", y="Valor_m2_millones", data = inmueble.query("Barrio in @top_barrio"))
ax.tick_params(axis="x", rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8)) 
ax = sns.boxplot(x="Barrio", y="Valor_m2_millones" , data = inmueble.query("Barrio in @top_barrio & Valor_m2_millones < 15 "))
ax.tick_params(axis="x", rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8)) 
ax = sns.boxplot(x="Barrio", y="Area" , data = inmueble.query("Barrio in @top_barrio &Area <500 "))
ax.tick_params(axis="x", rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x="Barrio", y="Valor_m2_Millon", data = inmueble.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     192             if is_local:
# --> 193                 return self.scope[key]
#     194
#
# /usr/lib/python3.9/collections/__init__.py in __getitem__(self, key)
#     940                 pass
# --> 941         return self.__missing__(key)            # support subclasses that define __missing__
#     942
#
# /usr/lib/python3.9/collections/__init__.py in __missing__(self, key)
#     932     def __missing__(self, key):
# --> 933         raise KeyError(key)
#     934
#
# KeyError: 'top_barrios'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...
